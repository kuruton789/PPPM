# %%
! nvidia-smi
# Out:
# Wed Apr 27 07:29:14 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    25W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os

class Config:
    AUTHOR = "kuruton"

    NAME = "USP-" + "Exp034-deberta-v3-base-epoch10"
    MODEL_PATH = "microsoft/deberta-v3-base"
    DATASET_PATH = [
        "yasufuminakama/cpc-data"
    ]

    COMPETITION = "us-patent-phrase-to-phrase-matching"
    COLAB_PATH = "/content/drive/Shareddrives/USPatent" 
    DRIVE_PATH = os.path.join(COLAB_PATH, AUTHOR)

    # ここに自分のAPIkeyのpathを書いてください！！！
    api_path = "/content/drive/MyDrive/kaggle.json"

    seed = 42
    num_fold = 4
    trn_fold = [0, 1, 2, 3]
    batch_size = 32
    n_epochs = 10
    max_len = 256

    weight_decay = 2e-5
    beta = (0.9, 0.98)
    lr = 1e-5
    num_warmup_steps_rate = 0.01
    clip_grad_norm = None
    gradient_accumulation_steps = 1
    num_eval = 1

    upload_from_colab = True

# %%
# ========================================
# Library
# ========================================
import os
import gc
import re
import sys
import json
import time
import shutil
import joblib
import random
import requests
import warnings
warnings.filterwarnings('ignore')
from ast import literal_eval

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import scipy 
import itertools
from pathlib import Path
from glob import glob
from tqdm.auto import tqdm
from sklearn.model_selection import (
    StratifiedKFold, 
    KFold, 
    GroupKFold
)
from sklearn.metrics import (
    accuracy_score, 
    f1_score,
    roc_auc_score,
)

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
from torch.cuda.amp import autocast, GradScaler

# %%
def setup(cfg):
    cfg.COLAB = 'google.colab' in sys.modules
    cfg.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    if cfg.COLAB:
        print('This environment is Google Colab')

        # mount
        from google.colab import drive
        if not os.path.isdir('/content/drive'):
            drive.mount('/content/drive') 

        # pip install
        ! pip install -q torch==1.10.0
        ! pip install -q transformers
        ! pip install -q sentencepiece

        # use kaggle api (need kaggle token)
        f = open(cfg.api_path, 'r')
        json_data = json.load(f) 
        os.environ['KAGGLE_USERNAME'] = json_data['username']
        os.environ['KAGGLE_KEY'] = json_data['key']

        # set dirs
        cfg.DRIVE = cfg.DRIVE_PATH
        cfg.EXP = (cfg.NAME if cfg.NAME is not None 
            else requests.get('http://172.28.0.2:9000/api/sessions').json()[0]['name'][:-6]
        )
        cfg.INPUT = os.path.join(cfg.DRIVE, 'Input')
        cfg.OUTPUT = os.path.join(cfg.DRIVE, 'Output')
        cfg.SUBMISSION = os.path.join(cfg.DRIVE, 'Submission')
        cfg.DATASET = os.path.join(cfg.DRIVE, 'Dataset')

        cfg.OUTPUT_EXP = os.path.join(cfg.OUTPUT, cfg.EXP) 
        cfg.EXP_MODEL = os.path.join(cfg.OUTPUT_EXP, 'model')
        cfg.EXP_FIG = os.path.join(cfg.OUTPUT_EXP, 'fig')
        cfg.EXP_PREDS = os.path.join(cfg.OUTPUT_EXP, 'preds')

        # make dirs
        for d in [cfg.INPUT, cfg.SUBMISSION, cfg.EXP_MODEL, cfg.EXP_FIG, cfg.EXP_PREDS]:
            os.makedirs(d, exist_ok=True)
        
        if not os.path.isfile(os.path.join(cfg.INPUT, 'train.csv')):
            # load dataset
            ! pip install --upgrade --force-reinstall --no-deps kaggle
            ! kaggle competitions download -c $cfg.COMPETITION -p $cfg.INPUT
            filepath = os.path.join(cfg.INPUT,cfg.COMPETITION+'.zip')
            ! unzip -d $cfg.INPUT $filepath
            
        
        for path in cfg.DATASET_PATH:
            datasetpath = os.path.join(cfg.DATASET,  path.split('/')[1])
            if not os.path.exists(datasetpath):
                os.makedirs(datasetpath, exist_ok=True)
                ! kaggle datasets download $path -p $datasetpath
                filepath = os.path.join(datasetpath, path.split("/")[1]+'.zip')
                ! unzip -d $datasetpath $filepath

    else:
        print('This environment is Kaggle Kernel')

        # set dirs
        cfg.INPUT = f'../input/{cfg.COMPETITION}'
        cfg.EXP = cfg.NAME
        cfg.OUTPUT_EXP = cfg.NAME
        cfg.SUBMISSION = './'
        cfg.DATASET = '../input/'
        
        cfg.EXP_MODEL = os.path.join(cfg.EXP, 'model')
        cfg.EXP_FIG = os.path.join(cfg.EXP, 'fig')
        cfg.EXP_PREDS = os.path.join(cfg.EXP, 'preds')

        # make dirs
        for d in [cfg.EXP_MODEL, cfg.EXP_FIG, cfg.EXP_PREDS]:
            os.makedirs(d, exist_ok=True)
    return cfg


def dataset_create_new(dataset_name, upload_dir):
    dataset_metadata = {}
    dataset_metadata['id'] = f'{os.environ["KAGGLE_USERNAME"]}/{dataset_name}'
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = dataset_name
    with open(os.path.join(upload_dir, 'dataset-metadata.json'), 'w') as f:
        json.dump(dataset_metadata, f, indent=4)
    api = KaggleApi()
    api.authenticate()
    api.dataset_create_new(folder=upload_dir, convert_to_csv=False, dir_mode='tar')

# %%
# =====================
# Utils
# =====================
# Seed
def set_seed(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# KFold
def get_kfold(train, n_splits, seed):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=seed)
    generator = kf.split(train)
    fold_series = []
    for fold, (idx_train, idx_valid) in enumerate(generator):
        fold_series.append(pd.Series(fold, index=idx_valid))
    fold_series = pd.concat(fold_series).sort_index()
    return fold_series

def get_stratifiedkfold(train, target_col, n_splits, seed):
    kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    generator = kf.split(train, train[target_col])
    fold_series = []
    for fold, (idx_train, idx_valid) in enumerate(generator):
        fold_series.append(pd.Series(fold, index=idx_valid))
    fold_series = pd.concat(fold_series).sort_index()
    return fold_series

def get_groupkfold(train, target_col, group_col, n_splits):
    kf = GroupKFold(n_splits=n_splits)
    generator = kf.split(train, train[target_col], train[group_col])
    fold_series = []
    for fold, (idx_train, idx_valid) in enumerate(generator):
        fold_series.append(pd.Series(fold, index=idx_valid))
    fold_series = pd.concat(fold_series).sort_index()
    return fold_series

# collatte
def collatte(inputs, labels=None):
    mask_len = int(inputs["attention_mask"].sum(axis=1).max())
    if not labels is None:
        inputs = {
            "input_ids" : inputs['input_ids'][:,:mask_len],
            "attention_mask" : inputs['attention_mask'][:,:mask_len],
        }
        labels =  labels[:,:mask_len]
        return inputs, labels, mask_len
                
    else:
        inputs = {
            "input_ids" : inputs['input_ids'][:,:mask_len],
            "attention_mask" : inputs['attention_mask'][:,:mask_len],
        }
        return inputs, mask_len

# =====================
# CPC Data
# =====================
def get_cpc_texts(cfg):
    contexts = []
    pattern = '[A-Z]\d+'
    for file_name in os.listdir(os.path.join(cfg.DATASET, 'cpc-data/CPCSchemeXML202105')):
        result = re.findall(pattern, file_name)
        if result:
            contexts.append(result)
    contexts = sorted(set(sum(contexts, [])))
    results = {}
    for cpc in ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'Y']:
        with open(os.path.join(cfg.DATASET, f'cpc-data/CPCTitleList202202/cpc-section-{cpc}_20220201.txt')) as f:
            s = f.read()
        pattern = f'{cpc}\t\t.+'
        result = re.findall(pattern, s)
        cpc_result = result[0].lstrip(pattern)
        for context in [c for c in contexts if c[0] == cpc]:
            pattern = f'{context}\t\t.+'
            result = re.findall(pattern, s)
            results[context] = cpc_result + ". " + result[0].lstrip(pattern)
    for key, val in results.items():
        results[key] = val.lower()
    return results

# %%
class TrainDataset(Dataset):
    def __init__(self, cfg, df):
        self.cfg = cfg
        self.texts = df['text'].values
        self.labels = df['score'].values

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, index):
        inputs = self.prepare_input(self.cfg, self.texts[index])
        label = torch.tensor(self.labels[index], dtype=torch.float)
        return inputs, label
    
    @staticmethod
    def prepare_input(cfg, text):
        inputs = cfg.tokenizer(
            text,
            add_special_tokens=True,
            max_length=cfg.max_len,
            padding="max_length",
            return_offsets_mapping=False
        )
        for k, v in inputs.items():
            inputs[k] = torch.tensor(v, dtype=torch.long)
        return inputs

class CustomModel(nn.Module):
    def __init__(self, cfg, criterion):
        super().__init__()
        self.cfg = cfg
        self.criterion = criterion
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.backbone = AutoModel.from_pretrained(
            cfg.MODEL_PATH, 
            config=self.config
        )
        self.fc = nn.Sequential(
            nn.Linear(self.config.hidden_size, 1),
        )

        self.dropout1 = nn.Dropout(0.1)
        self.dropout2 = nn.Dropout(0.2)
        self.dropout3 = nn.Dropout(0.3)
        self.dropout4 = nn.Dropout(0.4)
        self.dropout5 = nn.Dropout(0.5)

    def forward(self, inputs, labels=None):
        outputs = self.backbone(**inputs)["last_hidden_state"]
        outputs = outputs[:, 0, :]
        logits1 = self.fc(self.dropout1(outputs)).flatten()
        logits2 = self.fc(self.dropout2(outputs)).flatten()
        logits4 = self.fc(self.dropout3(outputs)).flatten()
        logits3 = self.fc(self.dropout4(outputs)).flatten()
        logits5 = self.fc(self.dropout5(outputs)).flatten()
        logits = (logits1 + logits2 + logits3 + logits4 + logits5) / 5
        
        loss = 0
        if labels is not None:
            loss1 = self.criterion(logits1, labels,)
            loss2 = self.criterion(logits2, labels)
            loss3 = self.criterion(logits3, labels)
            loss4 = self.criterion(logits4, labels)
            loss5 = self.criterion(logits5, labels)
            loss = (loss1 + loss2 + loss3 + loss4 + loss5) / 5

        return logits, loss

# %%
# evaluating
def evaluating(cfg, valid_loader, model, criterion, valid_df, fold, best_val_preds, best_val_score):
    # evaluating
    val_preds = []
    val_losses = []
    val_nums = []
    model.eval()
    with torch.no_grad():
        with tqdm(valid_loader, total=len(valid_loader)) as pbar:
            for (inputs, labels) in pbar:
                for k, v in inputs.items():
                    inputs[k] = v.to(cfg.device)
                labels = labels.to(cfg.device)
                with autocast():
                    output, loss = model(inputs, labels)
                output = output.sigmoid().detach().cpu().numpy()
                val_preds.append(output)
                val_losses.append(loss.item() * len(labels))
                val_nums.append(len(labels))
                pbar.set_postfix({
                    'val_loss': loss.item()
                })

    val_preds = np.concatenate(val_preds)
    val_loss = sum(val_losses) / sum(val_nums)
    corr_score = np.corrcoef(val_preds, valid_df['score'])[0, 1]

    val_log = {
        'val_loss': val_loss,
        'score': corr_score,
    }
    display(val_log)

    if best_val_score < corr_score:
        print("save model weight")
        best_val_preds = val_preds
        best_val_score = corr_score
        torch.save(
            model.state_dict(), 
            os.path.join(cfg.EXP_MODEL, f"fold{fold}.pth")
        )
    return best_val_preds, best_val_score


def training(cfg, train):
    # =====================
    # Training
    # =====================
    set_seed(cfg.seed)
    oof_pred = np.zeros(len(train), dtype=np.float32)
    for fold in cfg.trn_fold:
        # dataset, dataloader
        train_df = train.loc[cfg.folds!=fold]
        valid_df = train.loc[cfg.folds==fold]
        train_idx = list(train_df.index)
        valid_idx = list(valid_df.index)

        # reverse anchor_target
        # rev_train_df = train_df.copy()
        # rev_train_df[['anchor', 'target']] = rev_train_df[['target', 'anchor']].to_numpy()
        # train_df = pd.concat([train_df, rev_train_df]).reset_index(drop=True)

        train_dataset = TrainDataset(cfg, train_df)
        valid_dataset = TrainDataset(cfg, valid_df)
        train_loader = DataLoader(
            dataset=train_dataset, 
            batch_size=cfg.batch_size, 
            shuffle=True,
            pin_memory=True,
            drop_last=True
        )
        valid_loader = DataLoader(
            dataset=valid_dataset,
            batch_size=cfg.batch_size,
            shuffle=False,
            pin_memory=True,
            drop_last=False
        )
        # model-training
        criterion = nn.BCEWithLogitsLoss(reduction="mean")
        best_val_preds = None
        best_val_score = -1

        # model
        model = CustomModel(cfg, criterion)
        model = model.to(cfg.device)

        # optimizer, scheduler
        param_optimizer = list(model.named_parameters())
        no_decay = ['bias', 'LayerNorm.bias', 'LayerNorm.weight']
        optimizer_grouped_parameters = [
            {
                'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)], 
                'weight_decay': cfg.weight_decay
            },
            {
                'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)], 
                'weight_decay': 0.0
            }
        ]
        optimizer = AdamW(
            optimizer_grouped_parameters,
            lr=cfg.lr,
            betas=cfg.beta,
            weight_decay=cfg.weight_decay,
        )
        num_train_optimization_steps = int(
            len(train_loader) * cfg.n_epochs // cfg.gradient_accumulation_steps
        )
        num_warmup_steps = int(num_train_optimization_steps * cfg.num_warmup_steps_rate)
        scheduler = get_linear_schedule_with_warmup(
            optimizer,
            num_warmup_steps=num_warmup_steps,
            num_training_steps=num_train_optimization_steps
        )
        num_eval_step = len(train_loader) // cfg.num_eval + cfg.num_eval
        
        for epoch in range(cfg.n_epochs):
            # training
            print(f"# ============ start epoch:{epoch} ============== #")
            model.train() 
            val_losses_batch = []
            scaler = GradScaler()
            with tqdm(train_loader, total=len(train_loader)) as pbar:
                for step, (inputs, labels) in enumerate(pbar):
                    inputs, max_len = collatte(inputs)
                    for k, v in inputs.items():
                        inputs[k] = v.to(cfg.device)
                    labels = labels.to(cfg.device)

                    optimizer.zero_grad()
                    with autocast():
                        output, loss = model(inputs, labels)
                    pbar.set_postfix({
                        'loss': loss.item(),
                        'lr': scheduler.get_lr()[0]
                    })

                    if cfg.gradient_accumulation_steps > 1:
                        loss = loss / cfg.gradient_accumulation_steps

                    scaler.scale(loss).backward()
                    if cfg.clip_grad_norm is not None:
                        torch.nn.utils.clip_grad_norm_(
                            model.parameters(), 
                            cfg.clip_grad_norm
                        )
                    if (step+1) % cfg.gradient_accumulation_steps == 0:
                        scaler.step(optimizer)
                        scaler.update()
                        scheduler.step()

                    if step % num_eval_step == 0 and step != 0:
                        tmp_num_eval = step // num_eval_step
                        print(f'fold: {fold}, epoch: {epoch}, num_eval: {tmp_num_eval}')
                        best_val_preds, best_val_score = evaluating(
                            cfg, valid_loader,
                            model,
                            criterion,
                            valid_df,
                            fold,
                            best_val_preds,
                            best_val_score
                        )
                        model.train() 
            
            print(f'fold: {fold}, epoch: {epoch}, last')
            best_val_preds, best_val_score = evaluating(
                cfg, valid_loader,
                model,
                criterion,
                valid_df,
                fold,
                best_val_preds,
                best_val_score
            )

        oof_pred[valid_idx] = best_val_preds.astype(np.float32)
        np.save(os.path.join(cfg.EXP_PREDS, f'oof_pred_fold{fold}.npy'), best_val_preds)
        del model; gc.collect()

    np.save(os.path.join(cfg.EXP_PREDS, 'oof_pred.npy'), oof_pred)

    # =====================
    # scoring
    # =====================
    corr_score = np.corrcoef(oof_pred, train['score'])[0, 1]
    print('CV:', round(corr_score, 5))
    return corr_score

# %%
# =====================
# Main
# =====================
cfg = setup(Config)

import transformers
from transformers import AutoConfig, AutoModel, AutoTokenizer
from transformers import AdamW, get_linear_schedule_with_warmup

train = pd.read_csv(os.path.join(cfg.INPUT, 'train.csv'))
test = pd.read_csv(os.path.join(cfg.INPUT, 'test.csv'))
sub = pd.read_csv(os.path.join(cfg.INPUT, 'sample_submission.csv'))

cfg.tokenizer = AutoTokenizer.from_pretrained(cfg.MODEL_PATH)

cpc_texts = get_cpc_texts(cfg)
torch.save(cpc_texts, os.path.join(cfg.EXP_PREDS, "cpc_texts.pth"))
train['context_text'] = train['context'].map(cpc_texts)
train['text'] = train['anchor'] + '[SEP]' + train['target'] + '[SEP]' + train['context_text']

cfg.folds = get_groupkfold(train, 'score', 'anchor', cfg.num_fold)
cfg.folds.to_csv(os.path.join(cfg.EXP_PREDS, 'folds.csv'))

score = training(cfg, train)
if cfg.upload_from_colab and cfg.COLAB:
    from kaggle.api.kaggle_api_extended import KaggleApi
    dataset_create_new(dataset_name=Config.EXP, upload_dir=Config.OUTPUT_EXP)
# Out:
# This environment is Google Colab
# Mounted at /content/drive
#      |██████████████████████████████▎ | 834.1 MB 1.2 MB/s eta 0:00:41tcmalloc: large alloc 1147494400 bytes == 0x646e6000 @  0x7fed5de4e615 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x598e3b 0x511f68 0x598e3b 0x511f68 0x598e3b 0x511f68 0x4bc98a 0x532e76 0x594b72 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x5118f8 0x593dd7
#      |████████████████████████████████| 881.9 MB 18 kB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.12.0+cu113 requires torch==1.11.0, but you have torch 1.10.0 which is incompatible.
# torchtext 0.12.0 requires torch==1.11.0, but you have torch 1.10.0 which is incompatible.
# torchaudio 0.11.0+cu113 requires torch==1.11.0, but you have torch 1.10.0 which is incompatible.
#      |████████████████████████████████| 4.0 MB 4.2 MB/s
#      |████████████████████████████████| 77 kB 7.5 MB/s
#      |████████████████████████████████| 6.6 MB 53.6 MB/s
#      |████████████████████████████████| 596 kB 61.0 MB/s
#      |████████████████████████████████| 895 kB 58.9 MB/s
#      |████████████████████████████████| 1.2 MB 4.3 MB/s
# Collecting kaggle
#   Downloading kaggle-1.5.12.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 2.9 MB/s
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73051 sha256=3fda319c47fd97f160b80e0f03aef068a2954bec919b3dc69c0648b6a9fa0f68
#   Stored in directory: /root/.cache/pip/wheels/62/d6/58/5853130f941e75b2177d281eb7e44b4a98ed46dd155f556dc5
# Successfully built kaggle
# Installing collected packages: kaggle
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.5.12
#     Uninstalling kaggle-1.5.12:
#       Successfully uninstalled kaggle-1.5.12
# Successfully installed kaggle-1.5.12
# Downloading us-patent-phrase-to-phrase-matching.zip to /content/drive/Shareddrives/USPatent/kuruton/Input
#   0% 0.00/682k [00:00<?, ?B/s]
# 100% 682k/682k [00:00<00:00, 60.8MB/s]
# Archive:  /content/drive/Shareddrives/USPatent/kuruton/Input/us-patent-phrase-to-phrase-matching.zip
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Input/sample_submission.csv
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Input/test.csv
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Input/train.csv
# Downloading cpc-data.zip to /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data
#  62% 9.00M/14.4M [00:00<00:00, 8.99MB/s]
# 100% 14.4M/14.4M [00:00<00:00, 15.2MB/s]
# Archive:  /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/cpc-data.zip
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0931.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0932.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0933.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0934.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0935.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0936.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0937.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0938.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0939.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0940.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0941.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0942.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0943.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0944.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0945.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0946.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0947.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0948.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A01N-0949.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A61K-0950.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A61K-0951.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A61K-0952.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A61K-0953.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-A61K-1029.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0954.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0955.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0956.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0957.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0958.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0959.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0960.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0961.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0962.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0963.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0964.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0965.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0966.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0967.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0968.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0969.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0970.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0971.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0972.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0973.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0974.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0975.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0976.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0977.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0978.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0979.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0980.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0981.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0982.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0983.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0984.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0985.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0986.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07C-0987.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07D-0988.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07D-0989.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07D-0990.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07D-0991.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07D-0992.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07D-0993.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07D-0994.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07D-0995.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07D-1029.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07D-1030.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07D-1031.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07D-1032.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07F-0997.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07F-0998.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07F-0999.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07F-1000.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07F-1001.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07F-1002.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07F-1003.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07F-1004.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07F-1005.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07F-1006.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07F-1007.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07F-1008.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07H-1031.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07H-1032.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C07K-1009.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C08K-1010.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C08K-1011.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C08K-1012.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C09B-1013.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C09B-1014.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C09B-1015.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C09B-1016.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C09B-1017.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C09B-1018.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C09B-1019.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C09B-1020.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C09B-1021.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C09B-1022.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C09B-1023.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C09B-1024.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C09B-1025.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C10M-1026.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C10M-1027.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/Image/cpc-sch-C12P-1028.gif
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A01B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A01C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A01D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A01F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A01G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A01H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A01J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A01K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A01L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A01M.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A01N.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A21B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A21C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A21D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A22B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A22C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A23B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A23C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A23D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A23F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A23G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A23J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A23K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A23L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A23N.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A23P.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A23V.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A23Y.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A24B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A24C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A24D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A24F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A41B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A41C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A41D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A41F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A41G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A41H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A42B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A42C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A43B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A43C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A43D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A44B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A44C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A44D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A45B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A45C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A45D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A45F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A46B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A46D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A47B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A47C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A47D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A47F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A47G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A47H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A47J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A47K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A47L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A61B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A61C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A61D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A61F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A61G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A61H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A61J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A61K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A61L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A61M.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A61N.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A61P.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A61Q.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A62B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A62C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A62D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A63B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A63C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A63D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A63F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A63G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A63H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A63J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A63K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-A99Z.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B01B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B01D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B01F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B01J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B01L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B02B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B02C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B03B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B03C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B03D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B04B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B04C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B05B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B05C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B05D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B06B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B07B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B07C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B08B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B09B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B09C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B21B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B21C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B21D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B21F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B21G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B21H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B21J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B21K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B21L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B22C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B22D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B22F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B23B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B23C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B23D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B23F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B23G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B23H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B23K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B23P.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B23Q.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B24B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B24C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B24D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B25B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B25C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B25D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B25F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B25G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B25H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B25J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B26B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B26D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B26F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B27B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B27C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B27D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B27F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B27G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B27H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B27J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B27K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B27L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B27M.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B27N.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B28B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B28C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B28D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B29B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B29C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B29D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B29K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B29L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B30B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B31B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B31C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B31D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B31F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B32B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B33Y.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B41B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B41C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B41D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B41F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B41G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B41J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B41K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B41L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B41M.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B41N.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B41P.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B42B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B42C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B42D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B42F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B42P.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B43K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B43L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B43M.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B44B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B44C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B44D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B44F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60M.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60N.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60P.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60Q.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60R.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60S.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60T.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60V.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60W.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B60Y.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B61B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B61C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B61D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B61F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B61G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B61H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B61J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B61K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B61L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B62B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B62C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B62D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B62H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B62J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B62K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B62L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B62M.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B63B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B63C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B63G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B63H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B63J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B64B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B64C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B64D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B64F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B64G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B65B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B65C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B65D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B65F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B65G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B65H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B66B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B66C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B66D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B66F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B67B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B67C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B67D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B68B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B68C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B68F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B68G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B81B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B81C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B82B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B82Y.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-B99Z.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C01B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C01C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C01D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C01F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C01G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C01P.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C02F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C03B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C03C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C04B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C05B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C05C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C05D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C05F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C05G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C06B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-C06C.xml
# ...
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G05G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G06C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G06D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G06E.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G06F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G06G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G06J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G06K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G06M.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G06N.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G06Q.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G06T.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G07B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G07C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G07D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G07F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G07G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G08B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G08C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G08G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G09B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G09C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G09D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G09F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G09G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G10B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G10C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G10D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G10F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G10G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G10H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G10K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G10L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G11B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G11C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G12B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G16B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G16C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G16H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G16Y.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G16Z.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G21B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G21C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G21D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G21F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G21G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G21H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G21J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G21K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-G99Z.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H01B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H01C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H01F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H01G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H01H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H01J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H01K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H01L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H01M.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H01P.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H01Q.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H01R.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H01S.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H01T.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H02B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H02G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H02H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H02J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H02K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H02M.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H02N.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H02P.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H02S.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H03B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H03C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H03D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H03F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H03G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H03H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H03J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H03K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H03L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H03M.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H04B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H04H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H04J.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H04K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H04L.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H04M.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H04N.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H04Q.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H04R.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H04S.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H04T.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H04W.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H05B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H05C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H05F.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H05G.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H05H.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H05K.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-H99Z.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-Y.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-Y02A.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-Y02B.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-Y02C.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-Y02D.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-Y02E.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-Y02P.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-Y02T.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-Y02W.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-Y04S.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-Y10S.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme-Y10T.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCSchemeXML202105/cpc-scheme.xml
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCTitleList202202/cpc-section-A_20220201.txt
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCTitleList202202/cpc-section-B_20220201.txt
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCTitleList202202/cpc-section-C_20220201.txt
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCTitleList202202/cpc-section-D_20220201.txt
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCTitleList202202/cpc-section-E_20220201.txt
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCTitleList202202/cpc-section-F_20220201.txt
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCTitleList202202/cpc-section-G_20220201.txt
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCTitleList202202/cpc-section-H_20220201.txt
#   inflating: /content/drive/Shareddrives/USPatent/kuruton/Dataset/cpc-data/CPCTitleList202202/cpc-section-Y_20220201.txt
# Downloading:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/579 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.35M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Downloading:   0%|          | 0.00/354M [00:00<?, ?B/s]
# Some weights of the model checkpoint at microsoft/deberta-v3-base were not used when initializing DebertaV2Model: ['lm_predictions.lm_head.bias', 'lm_predictions.lm_head.dense.bias', 'mask_predictions.classifier.bias', 'mask_predictions.LayerNorm.weight', 'lm_predictions.lm_head.LayerNorm.weight', 'mask_predictions.LayerNorm.bias', 'mask_predictions.dense.bias', 'lm_predictions.lm_head.dense.weight', 'lm_predictions.lm_head.LayerNorm.bias', 'mask_predictions.classifier.weight', 'mask_predictions.dense.weight']
# - This IS expected if you are initializing DebertaV2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaV2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# # ============ start epoch:0 ============== #
#   0%|          | 0/854 [00:00<?, ?it/s]
